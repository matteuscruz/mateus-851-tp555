# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Exemplo 1:

# %% [markdown]
# Felipe, ao tentar executar o código apresentado em aula me deparei com uma mensagem condizendo que haveria um erro no código referente a propriedade 'Normed' utilizada no histograma. Em uma breve pesquisa me deparei com a solução de utilizar o parâmetro "Density" ao invés de "Normed" pois esta estaria sendo descontinuada e os erros não aconteceram mais. De qualquer forma o formato do slide também esta presente no final deste notebook.

# %%
import matplotlib.pyplot as plt

import numpy as np

# %matplotlib inline

data = np.random.randn(1000000)

plt.subplot(1,2,1)
plt.title('PDF')
plt.hist(data, bins=100, density=True, color='b')

plt.subplot(1,2,2)
plt.title('CDF')
plt.hist(data, bins=100, density=True, color='g', cumulative=True)
# Out:
# (array([1.00000e-06, 3.00000e-06, 4.00000e-06, 9.00000e-06, 1.30000e-05,
#         2.10000e-05, 3.70000e-05, 5.90000e-05, 8.50000e-05, 1.29000e-04,
#         1.84000e-04, 2.70000e-04, 3.76000e-04, 5.22000e-04, 7.32000e-04,
#         1.02300e-03, 1.42800e-03, 1.97500e-03, 2.69200e-03, 3.56100e-03,
#         4.75900e-03, 6.32000e-03, 8.25200e-03, 1.06980e-02, 1.37630e-02,
#         1.75540e-02, 2.22280e-02, 2.79350e-02, 3.47200e-02, 4.28620e-02,
#         5.27210e-02, 6.40730e-02, 7.73590e-02, 9.23180e-02, 1.09241e-01,
#         1.28656e-01, 1.50268e-01, 1.74194e-01, 2.00364e-01, 2.28412e-01,
#         2.58942e-01, 2.91153e-01, 3.25241e-01, 3.60829e-01, 3.98013e-01,
#         4.36030e-01, 4.74387e-01, 5.13190e-01, 5.51600e-01, 5.89818e-01,
#         6.26710e-01, 6.62833e-01, 6.97410e-01, 7.30347e-01, 7.61670e-01,
#         7.90661e-01, 8.17473e-01, 8.41814e-01, 8.64005e-01, 8.83794e-01,
#         9.01672e-01, 9.17443e-01, 9.31276e-01, 9.43413e-01, 9.53689e-01,
# ...

# %% [markdown]
# Exemplo 2:

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import axes3d

# %matplotlib notebook

ax = plt.subplot(111, projection='3d')
X,Y,Z = axes3d.get_test_data(0.1)
ax.plot_wireframe(X,Y,Z)

plt.savefig('figura3d.png')
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %% [markdown]
# Exemplo 3:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# %matplotlib inline

x = np.arange(-10,10,0.1)

y = 12 + 3 * np.exp(-0.05 * x) + 1.4 * np.sin(1.2 * x) + 2.1 * np.sin(-2.2 * x + 3)

np.random.seed(42)

y_noise = y + np.random.normal(0, 0.5, size = len(y))

mlp= MLPRegressor(hidden_layer_sizes=(30,20,10), max_iter=10000, solver='lbfgs', alpha=0.9, activation='tanh')
yfit= mlp.fit(x[:, None], y_noise).predict(x[:, None])

plt.figure(figsize= (10,8))
plt.plot(x, y_noise, 'o', label = 'dado original + ruido')
plt.plot(x, y, 'k', label = 'dado original')
plt.plot(x, yfit, '-r', label = 'curvaajustadacom MLP', zorder= 10)
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
# Out:
# D:\Anaconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Text(0, 0.5, 'y')
